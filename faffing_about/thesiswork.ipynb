# %% [markdown]
# # File for Playing Around With Thesis Code

# %%
using Pkg

# Activate the package repo itself
Pkg.activate("..")

# Make sure deps are installed
Pkg.instantiate()

using ImageView, Phylo, Plots, FASTX, MolecularEvolution, CodonMolecularEvolution, JLD2, MCMCChains, StatsPlots, MCMCDiagnosticTools, Measures, BenchmarkTools
# Out:
#   Activating project at `c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1`

# %%
analysis_name = "output/Ace2"
seqnames,seqs = read_fasta("../test/data/Ace2_tiny/Ace2_tiny_tagged.fasta");
treestring = readlines(open("../test/data/Ace2_tiny/tiny_tagged_no_bg.tre"))[1]
tags = ["{G1}", "{G2}"]
grid = FAMEgrid(seqnames, seqs, treestring)
# Out:
# Step 1: Initialization.
# Step 2: Optimizing global codon model parameters.
# ┌ Warning: XM_015126958_Macaca_mulatta{G2} on tree but not found in names.
# └ @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:102
# MethodError: no method matching identity!(::LazyPartition{NucleotidePartition})
#
# The function `identity!` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   identity!(!Matched::GaussianPartition)
#
#    @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\models\continuous_models\gaussian_partition.jl:61
#
#   identity!(!Matched::CATPartition{PType}) where PType<:DiscretePartition
#
#    @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\models\compound_models\cat.jl:36
#
#   identity!(!Matched::SWMPartition)
#
#    @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\models\compound_models\swm.jl:77
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#   [1] _broadcast_getindex_evalf
#
#     @ .\broadcast.jl:678 [inlined]
#
#   [2] _broadcast_getindex
#
#     @ .\broadcast.jl:651 [inlined]
#
#   [3] getindex
#
#     @ .\broadcast.jl:610 [inlined]
#
#   [4] copy
#
#     @ .\broadcast.jl:911 [inlined]
#
#   [5] materialize
#
#     @ .\broadcast.jl:872 [inlined]
#
#   [6] uninformative_message!(message::Vector{Partition})
#
#     @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:74
#
#   [7] populate_tree!(tree::FelNode, starting_message::Vector{LazyPartition{NucleotidePartition}}, names::Vector{String}, data::Vector{String}; init_all_messages::Bool, tolerate_missing::Int64, leaf_name_transform::CodonMolecularEvolution.var"#290#294")
#
#     @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:104
#
#   [8] populate_tree!(tree::FelNode, starting_partition::LazyPartition{NucleotidePartition}, names::Vector{String}, data::Vector{String}; init_all_messages::Bool, tolerate_missing::Int64, leaf_name_transform::Function)
#
#     @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:132
#
#   [9] populate_tree!
#
#     @ C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:123 [inlined]
#
#  [10] optimize_nuc_mu(seqnames::Vector{String}, seqs::Vector{String}, tree::FelNode; leaf_name_transform::Function, genetic_code::MolecularEvolution.GeneticCode, optimize_branch_lengths::Bool)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\shared\shared.jl:264
#
#  [11] optimize_nuc_mu
#
#     @ c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\shared\shared.jl:254 [inlined]
#
#  [12] difFUBAR_global_fit_2steps(seqnames::Vector{String}, seqs::Vector{String}, tree::FelNode, leaf_name_transform::Function, code::MolecularEvolution.GeneticCode; verbosity::Int64, optimize_branch_lengths::Bool)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\difFUBAR\difFUBAR.jl:100
#
#  [13] difFUBAR_global_fit_2steps
#
#     @ c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\difFUBAR\difFUBAR.jl:96 [inlined]
#
#  [14] FAMEgrid(seqnames::Vector{String}, seqs::Vector{String}, treestring::String; verbosity::Int64, code::MolecularEvolution.GeneticCode, optimize_branch_lengths::Bool)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\FAME\FAME.jl:21
#
#  [15] FAMEgrid(seqnames::Vector{String}, seqs::Vector{String}, treestring::String)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\FAME\FAME.jl:18
#
#  [16] top-level scope
#
#     @ c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\faffing_about\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:5

# %%
analysis_name = "output/Ace2"
seqnames,seqs = read_fasta("../test/data/Ace2_tiny/Ace2_tiny_tagged.fasta");
treestring = readlines(open("../test/data/Ace2_tiny/tiny_tagged_no_bg.tre"))[1]
tags = ["{G1}", "{G2}"]
flavorgrid = FLAVORgrid(seqnames, seqs, treestring)
grid = FAMEgrid(seqnames, seqs, treestring)
# Out:
# Step 1: Initialization.
# Step 2: Optimizing global codon model parameters.
# ┌ Warning: XM_015126958_Macaca_mulatta{G2} on tree but not found in names.
# └ @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:102
# MethodError: no method matching identity!(::LazyPartition{NucleotidePartition})
#
# The function `identity!` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   identity!(!Matched::GaussianPartition)
#
#    @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\models\continuous_models\gaussian_partition.jl:61
#
#   identity!(!Matched::CATPartition{PType}) where PType<:DiscretePartition
#
#    @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\models\compound_models\cat.jl:36
#
#   identity!(!Matched::SWMPartition)
#
#    @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\models\compound_models\swm.jl:77
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#   [1] _broadcast_getindex_evalf
#
#     @ .\broadcast.jl:678 [inlined]
#
#   [2] _broadcast_getindex
#
#     @ .\broadcast.jl:651 [inlined]
#
#   [3] getindex
#
#     @ .\broadcast.jl:610 [inlined]
#
#   [4] copy
#
#     @ .\broadcast.jl:911 [inlined]
#
#   [5] materialize
#
#     @ .\broadcast.jl:872 [inlined]
#
#   [6] uninformative_message!(message::Vector{Partition})
#
#     @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:74
#
#   [7] populate_tree!(tree::FelNode, starting_message::Vector{LazyPartition{NucleotidePartition}}, names::Vector{String}, data::Vector{String}; init_all_messages::Bool, tolerate_missing::Int64, leaf_name_transform::CodonMolecularEvolution.var"#246#250")
#
#     @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:104
#
#   [8] populate_tree!(tree::FelNode, starting_partition::LazyPartition{NucleotidePartition}, names::Vector{String}, data::Vector{String}; init_all_messages::Bool, tolerate_missing::Int64, leaf_name_transform::Function)
#
#     @ MolecularEvolution C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:132
#
#   [9] populate_tree!
#
#     @ C:\Users\toven\.julia\packages\MolecularEvolution\rRKnS\src\utils\misc.jl:123 [inlined]
#
#  [10] optimize_nuc_mu(seqnames::Vector{String}, seqs::Vector{String}, tree::FelNode; leaf_name_transform::Function, genetic_code::MolecularEvolution.GeneticCode, optimize_branch_lengths::Bool)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\shared\shared.jl:264
#
#  [11] optimize_nuc_mu
#
#     @ c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\shared\shared.jl:254 [inlined]
#
#  [12] difFUBAR_global_fit_2steps(seqnames::Vector{String}, seqs::Vector{String}, tree::FelNode, leaf_name_transform::Function, code::MolecularEvolution.GeneticCode; verbosity::Int64, optimize_branch_lengths::Bool)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\difFUBAR\difFUBAR.jl:100
#
#  [13] difFUBAR_global_fit_2steps
#
#     @ c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\difFUBAR\difFUBAR.jl:96 [inlined]
#
#  [14] FLAVORgrid(seqnames::Vector{String}, seqs::Vector{String}, treestring::String; verbosity::Int64, code::MolecularEvolution.GeneticCode, optimize_branch_lengths::Bool)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\FLAVOR\FLAVOR.jl:22
#
#  [15] FLAVORgrid(seqnames::Vector{String}, seqs::Vector{String}, treestring::String)
#
#     @ CodonMolecularEvolution c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\src\FLAVOR\FLAVOR.jl:19
#
#  [16] top-level scope
#
#     @ c:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\faffing_about\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:5

# %%
Pkg.status("MolecularEvolution")
# Out:
# Project CodonMolecularEvolution v0.1.0
# Status `C:\Users\toven\Documents\tove-code\MurrellLab\CodonMolecularEvolution.jl-1\Project.toml`
#   [9f975960] MolecularEvolution v0.2.7
